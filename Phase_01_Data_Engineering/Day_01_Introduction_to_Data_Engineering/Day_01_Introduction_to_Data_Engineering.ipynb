# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd

# %%
df=pd.read_csv('student_performance.csv')

# %%
df.head()
# Out:
#    student_id          name  age  gender        department  semester  \
# 0        1001  Aarav Sharma   19    Male  Computer Science         2
# 1        1002   Priya Patel   20  Female  Computer Science         2
# 2        1003   Rohit Verma   19    Male       Electronics         2
# 3        1004   Sneha Reddy   20  Female        Mechanical         2
# 4        1005    Arjun Nair   19    Male  Computer Science         2
#
#    math_score  science_score  english_score  programming_score  \
# 0          85             78             72                 91
# 1          76             82             88                 79
# 2          65             74             61                 55
# 3          70             80             75                 48
# 4          92             88             81                 95
#
#    attendance_percentage       city  admission_year
# 0                     92     Mumbai            2023
# 1                     87  Ahmedabad            2023
# ...

# %%
df.tail()
# Out:
#     student_id            name  age  gender        department  semester  \
# 25        1026      Rekha Nair   20  Female       Electronics         2
# 26        1027   Gaurav Shukla   21    Male  Computer Science         2
# 27        1028   Sunita Pillai   19  Female             Civil         2
# 28        1029      Nitin Jain   20    Male        Mechanical         2
# 29        1030  Akanksha Yadav   19  Female  Computer Science         2
#
#     math_score  science_score  english_score  programming_score  \
# 25          72             77             73                 63
# 26          84             79             75                 87
# 27          60             65             68                 39
# 28          75             76             70                 50
# 29          91             93             87                 94
#
#     attendance_percentage                city  admission_year
# 25                     82               Kochi            2023
# ...

# %%
df.shape[0]
# Out:
# 30

# %%
df.shape[0:6]
# Out:
# (30, 13)

# %%
print(df.name.tolist())
# Out:
# ['Aarav Sharma', 'Priya Patel', 'Rohit Verma', 'Sneha Reddy', 'Arjun Nair', 'Meera Joshi', 'Kiran Kumar', 'Divya Singh', 'Rahul Mishra', 'Ananya Das', 'Vikram Iyer', 'Pooja Gupta', 'Suresh Rao', 'Kavya Nambiar', 'Ajay Tiwari', 'Ritu Agarwal', 'Manoj Pandey', 'Swati Kulkarni', 'Deepak Chauhan', 'Nisha Kapoor', 'Harish Pillai', 'Tanvi Mehta', 'Sanjay Dubey', 'Preeti Saxena', 'Amit Bose', 'Rekha Nair', 'Gaurav Shukla', 'Sunita Pillai', 'Nitin Jain', 'Akanksha Yadav']

# %%
df.dtypes
# Out:
# student_id                int64
# name                     object
# age                       int64
# gender                   object
# department               object
# semester                  int64
# math_score                int64
# science_score             int64
# english_score             int64
# programming_score         int64
# attendance_percentage     int64
# city                     object
# admission_year            int64
# dtype: object

# %%
df.describe()
# Out:
#         student_id        age  semester  math_score  science_score  \
# count    30.000000  30.000000      30.0   30.000000      30.000000
# mean   1015.500000  19.733333       2.0   76.066667      77.833333
# std       8.803408   0.739680       0.0   11.467896       8.554423
# min    1001.000000  19.000000       2.0   56.000000      61.000000
# 25%    1008.250000  19.000000       2.0   67.250000      71.250000
# 50%    1015.500000  20.000000       2.0   75.500000      78.000000
# 75%    1022.750000  20.000000       2.0   85.750000      83.750000
# max    1030.000000  21.000000       2.0   95.000000      93.000000
#
#        english_score  programming_score  attendance_percentage  admission_year
# count      30.000000          30.000000              30.000000            30.0
# mean       74.166667          67.600000              84.500000          2023.0
# std        10.003735          21.041175               9.379913             0.0
# ...

# %%
df.isnull().sum()
# Out:
# student_id               0
# name                     0
# age                      0
# gender                   0
# department               0
# semester                 0
# math_score               0
# science_score            0
# english_score            0
# programming_score        0
# attendance_percentage    0
# city                     0
# admission_year           0
# dtype: int64

# %%
df = df[df['math_score'] != 5]

# %%
df = df.fillna(df.mean(numeric_only=True))

# %%
df=df.dropna()

# %%
display(df)
# Out:
#     student_id            name  age  gender        department  semester  \
# 0         1001    Aarav Sharma   19    Male  Computer Science         2
# 1         1002     Priya Patel   20  Female  Computer Science         2
# 2         1003     Rohit Verma   19    Male       Electronics         2
# 3         1004     Sneha Reddy   20  Female        Mechanical         2
# 4         1005      Arjun Nair   19    Male  Computer Science         2
# 5         1006     Meera Joshi   20  Female       Electronics         2
# 6         1007     Kiran Kumar   21    Male             Civil         2
# 7         1008     Divya Singh   19  Female  Computer Science         2
# 8         1009    Rahul Mishra   20    Male        Mechanical         2
# 9         1010      Ananya Das   19  Female  Computer Science         2
# 10        1011     Vikram Iyer   20    Male       Electronics         2
# 11        1012     Pooja Gupta   19  Female             Civil         2
# ...

# %%
df=df[df['math_score']!=5]
display(df.head())
# Out:
#    student_id          name  age  gender        department  semester  \
# 0        1001  Aarav Sharma   19    Male  Computer Science         2
# 1        1002   Priya Patel   20  Female  Computer Science         2
# 2        1003   Rohit Verma   19    Male       Electronics         2
# 3        1004   Sneha Reddy   20  Female        Mechanical         2
# 4        1005    Arjun Nair   19    Male  Computer Science         2
#
#    math_score  science_score  english_score  programming_score  \
# 0          85             78             72                 91
# 1          76             82             88                 79
# 2          65             74             61                 55
# 3          70             80             75                 48
# 4          92             88             81                 95
#
#    attendance_percentage       city  admission_year
# 0                     92     Mumbai            2023
# 1                     87  Ahmedabad            2023
# ...

# %%
print(df['department'].value_counts())
# Out:
# department
# Computer Science    13
# Electronics          6
# Mechanical           6
# Civil                5
# Name: count, dtype: int64

# %%
print(df['gender'].value_counts())
# Out:
# gender
# Male      15
# Female    15
# Name: count, dtype: int64

# %%
print(df['city'].value_counts())
# Out:
# city
# Kochi                 2
# Lucknow               2
# Thiruvananthapuram    2
# Agra                  2
# Kolkata               2
# Hyderabad             1
# Mumbai                1
# Delhi                 1
# Ahmedabad             1
# Varanasi              1
# Bangalore             1
# Pune                  1
# Jaipur                1
# Mysore                1
# Thrissur              1
# Bhopal                1
# Chennai               1
# Patna                 1
# Nagpur                1
# Dehradun              1
# Chandigarh            1
# Surat                 1
# Allahabad             1
# Kanpur                1
# Indore                1
# Name: count, dtype: int64

# %%
Mechanicalstd=df[df['department']=='Mechanical']
print(f"number Mechanical std: {len(Mechanicalstd)}")
# Out:
# number Mechanical std: 6

# %%
print(df[df['programming_score']=='mumbai'])
# Out:
# Empty DataFrame
# Columns: [student_id, name, age, gender, department, semester, math_score, science_score, english_score, programming_score, attendance_percentage, city, admission_year]
# Index: []

# %%
chennai_students = df[df['city'] == 'Chennai']
display(chennai_students[['name', 'math_score', 'science_score', 'english_score', 'programming_score']])

# %%
city_students = df[(df['city'] == 'Chennai') | (df['city'] == 'Mumbai')]
display(city_students[['name', 'programming_score']])
# Out:
#             name  programming_score
# 0   Aarav Sharma                 91
# 10   Vikram Iyer                 72

# %%
city_students_and = df[(df['city'] == 'Chennai') & (df['city'] == 'Mumbai')]
display(city_students_and[['name', 'programming_score']])
# Out:
# Empty DataFrame
# Columns: [name, programming_score]
# Index: []

# %%
high_att=df[df['attendance_percentage']<=75]
print(high_att)
# Out:
#     student_id           name  age  gender        department  semester  \
# 5         1006    Meera Joshi   20  Female       Electronics         2
# 8         1009   Rahul Mishra   20    Male        Mechanical         2
# 14        1015    Ajay Tiwari   19    Male  Computer Science         2
# 16        1017   Manoj Pandey   21    Male             Civil         2
# 20        1021  Harish Pillai   20    Male       Electronics         2
# 22        1023   Sanjay Dubey   21    Male             Civil         2
# 27        1028  Sunita Pillai   19  Female             Civil         2
#
#     math_score  science_score  english_score  programming_score  \
# 5           58             66             70                 52
# 8           62             71             58                 45
# 14          71             69             64                 76
# 16          56             61             55                 38
# 20          64             70             67                 58
# ...

# %%
display(df['attendance_percentage'])
# Out:
# 0     92
# 1     87
# 2     78
# 3     95
# 4     90
# 5     72
# 6     85
# 7     96
# 8     68
# 9     98
# 10    83
# 11    80
# 12    88
# 13    91
# 14    75
# 15    93
# 16    65
# 17    94
# 18    77
# 19    89
# 20    74
# 21    97
# 22    70
# 23    86
# 24    91
# 25    82
# 26    87
# 27    73
# 28    84
# 29    95
# Name: attendance_percentage, dtype: int64

# %%
df['tot']=df['math_score']+df['science_score']+df['english_score']+df['programming_score']
display(df['tot'])
# Out:
# 0     326
# 1     325
# 2     255
# 3     273
# 4     356
# 5     246
# 6     247
# 7     356
# 8     236
# 9     371
# 10    295
# 11    262
# 12    334
# 13    285
# 14    280
# 15    325
# 16    210
# 17    354
# 18    252
# 19    327
# 20    259
# 21    367
# 22    228
# 23    287
# 24    336
# 25    285
# 26    325
# 27    232
# 28    271
# 29    365
# Name: tot, dtype: int64

# %%
least=df.loc[df['tot'].idxmin()]
print(least)
# Out:
# student_id                       1017
# name                     Manoj Pandey
# age                                21
# gender                           Male
# department                      Civil
# semester                            2
# math_score                         56
# science_score                      61
# english_score                      55
# programming_score                  38
# attendance_percentage              65
# city                            Patna
# admission_year                   2023
# tot                               210
# Name: 16, dtype: object
