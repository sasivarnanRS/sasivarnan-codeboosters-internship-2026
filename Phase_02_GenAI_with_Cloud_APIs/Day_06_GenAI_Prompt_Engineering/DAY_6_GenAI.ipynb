# %%
# !pip install huggingface_hub --q

# %%
from transformers import pipeline

classifier=pipeline("sentiment-analysis",model="distilbert-base-uncased-finetuned-sst-2-english")

text=input("Enter text to Analyze")
result=classifier(text)
print(result)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Enter text to AnalyzeHello
# [{'label': 'POSITIVE', 'score': 0.9995185136795044}]

# %%
from transformers import pipeline

generator = pipeline("text-generation",model="gpt2")
prompt="In a future where healthcare is fully decentralized"
outputs=generator(prompt,max_new_tokens=80,do_sample=True,temperature=0.5,
                  top_p=0.9,num_return_sequences=0)

for i,out in enumerate(outputs):
  print(f"--- generated {i} ---")
  print(out['generated_text'])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=80) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# --- generated 0 ---
# In a future where healthcare is fully decentralized, it's not hard to see why it would be a good idea to create a separate system for healthcare.
#
# The other thing to keep in mind is that in the future, there will be a lot of different kinds of healthcare. There will be a lot of different types of healthcare, but the fundamental principles will be the same. The idea of a system where you can have different types of

# %%
from getpass import getpass
import os

HF_TOKEN= getpass("Enter your Hugging Face Token: ")
os.environ["HF_TOKEN"] = HF_TOKEN
# Out:
# Enter your Hugging Face Token: ··········

# %%
from huggingface_hub import  InferenceClient
import os

MODEL_ID="meta-llama/Meta-Llama-3-8B-Instruct"
client=InferenceClient(token=os.environ["HF_TOKEN"],model=MODEL_ID)

def extract_text(resp):
  try:
    return resp.choices[0].message.content
  except Exception:
    try:
      return resp['choices'][0]['message']['content']
    except:
      return str(resp)

messages=[
    {"role":"system","content":"You are a Helpful leetcode problem solver"},
    {"role":"user","content":"Explain Two Sum problem code simply with a python example"}
]

resp=client.chat_completion(messages=messages,max_tokens=400)
print(extract_text(resp))
# Out:
# The Two Sum problem is a classic problem in LeetCode, and it's a great example of how to solve a problem using a simple and efficient algorithm.
#
# **Problem Statement:**
#
# Given an array of integers, return indices of the two numbers such that they add up to a specific target.
#
# **Example:**
#
# Input: `nums = [2, 7, 11, 15], target = 9`
# Output: `[0, 1]` (because `nums[0] + nums[1] = 2 + 7 = 9`)
#
# **Python Solution:**
# ```python
# def twoSum(nums, target):
#     num_to_index = {}
#     for i, num in enumerate(nums):
#         complement = target - num
#         if complement in num_to_index:
#             return [num_to_index[complement], i]
#         num_to_index[num] = i
#     return []
# ```
# **Explanation:**
#
# 1. We create an empty dictionary `num_to_index` to store the indices of the numbers in the input array.
# 2. We iterate through the input array using `enumerate`, which gives us the index `i` and the value `num` of each element.
# 3. For each element, we calculate the "complement" by subtracting the current number from the target sum. This is the number we need to find to add up to the target sum.
# 4. We check if the complement is already in the `num_to_index` dictionary. If it is, it means we've found the two numbers that add up to the target sum, and we return their indices.
# 5. If the complement is not in the dictionary, we add the current number and its index to the dictionary.
# 6. If we reach the end of the array without finding the two numbers, we return an empty list.
#
# **Time Complexity:**
#
# The time complexity of this solution is O(n), where n is the length of the input array. This
