# %%
# !pip install chromadb sentence-transformers -q
print("Installation complete!")

# %%
import pandas as pd
import numpy as np

from sentence_transformers import SentenceTransformer
import chromadb

print("All libraries imported successfully!")
print(f"ChromaDB version: {chromadb.__version__}")

# %%
documents=[
    "MS Dhoni is the captain of India",
    "CSK is the best IPL team ever",
    "CSK has won 5 IPL trophies",
    "MSD won the ICC trophies for India in all formats"
]

query_keyword="CSK"
print("="*60)
print(f"KEYWORD SEARCH for: '{query_keyword}'")
print("="*60)

for i,doc in enumerate(documents):
  if query_keyword.lower() in doc.lower():
    print(f"  FOUND   [doc_{i}]:{doc}")
  else:
    print(f"  MISSED  [doc_{i}]:{doc}")

print()

# %%
# !pip install llama-index llama-index-llms-groq sentence-transformers --q

# %%
# !pip install llama-index-embeddings-huggingface --q

# %%
import os
from textwrap import dedent

os.makedirs("data",exist_ok=True)

file_path="data/sece_dept.txt"

content=dedent("""
SRI ESHWAR COLLEGE OF ENGINEERING (SECE)
DEPARTMENT OF ARTIFICIAL INTELLIGENCE & DATA SCIENCE (AI&DS)

============================================================
OVERVIEW
============================================================

Highest Salary Package: 44 LPA
Recruiters: 120+
Publications: 30+
Patents: 10+

------------------------------------------------------------
PROGRAMME SCOPE
------------------------------------------------------------

The biggest technological advancement of this century is enabling machines to think and act like humans through Artificial Intelligence powered by Data. AI-driven solutions are becoming dominant in every aspect of human life. Examples include Autonomous Vehicles, Virtual Assistants (Alexa, Siri), Domestic Assistant Robots, and many emerging intelligent systems.

AI & Data Science is one of the most promising fields for students interested in data, analytics, and intelligent systems.

------------------------------------------------------------
LEARNING SCOPE
------------------------------------------------------------

Students will be able to:

• Design, develop, and apply AI & DS solutions for real-world business problems.
• Develop analytical and critical thinking skills.
• Gain expertise in:
  - Deep Learning
  - Computer Vision
  - Data Science
  - Predictive Analytics
  - AR/VR
  - Natural Language Processing
  - Robotics
  - Software Technologies
  - Object-Oriented Programming
  - Database Management Systems

------------------------------------------------------------
CAREER PROGRESSION
------------------------------------------------------------

Career opportunities include:

• Data Scientist
• Data Analyst
• Machine Learning Architect
• Software Developer

Industries:
• Healthcare
• Travel & Transportation
• FMCG
• Technology & Analytics

============================================================
VISION
============================================================

To build a conducive academic and research environment in Artificial Intelligence and Data Science for enabling global education, research, and entrepreneurship.

============================================================
MISSION
============================================================

1. Update and enrich curriculum by integrating global trends and technological advancements.
2. Promote research through state-of-the-art infrastructure and emerging technologies.
3. Empower faculty through continuous upskilling, international collaborations, and research engagement.
4. Encourage industry-aligned learning, innovation, and entrepreneurship for solving societal challenges.

============================================================
PROGRAMME DETAILS
============================================================

• Programme Educational Objectives (PEOs)
• Programme Outcomes (POs)
• Programme Specific Outcomes (PSOs)
• Curriculum & Syllabus
• Programme Assessment Committee
• Board of Studies

============================================================
CORPORATE ADVISORY BOARD
============================================================

1. Mr. Subrahmanian Kumaraswamy
   Data Architect, NTT Data

2. Mr. Bagavath P
   Technical Lead, BNY Mellon Technology

3. Mr. A. Ravi Kasthuri
   CTO, Presentation.AI

4. Mr. Karthick Shanmugasundaram
   Senior Software Developer, GUSTO, USA

5. Ms. Aishwarya Sterling James
   Senior Executive, Mad Street Den (Vue.ai)

============================================================
ENHANCED LEARNING
============================================================

LABORATORIES
------------
• Programming Languages Laboratory
• Full Stack Development Laboratory
• Artificial Intelligence Laboratory
• Data Science Laboratory
• Data Visualization & Exploration Laboratory
• Machine Learning Laboratory
• Computer Vision Laboratory
• Natural Language Programming Laboratory

CENTRES OF EXCELLENCE (CoE)
---------------------------
• CoE in Data Science
• CoE in AI and Robotics

VALUE ADDED COURSES
-------------------
• Mastering OpenCV
• Application Development using KNIME
• Mastering TensorFlow and Keras
• Apache Spark and Databricks
• Application Development using Golang
• Prompt Engineering

INNOVATIVE TEACHING METHODS
---------------------------
• Experiential Learning through Python Frameworks
• Team Assisted Individualization using Google Colab
• Dashboard Creation using Visualization Tools
• Carnegie Learning for Case-Based Analysis
• Personalized Learning using Squirrel AI

============================================================
HEAD OF THE DEPARTMENT
============================================================

Dr. G. Sathish Kumar
Associate Professor & HOD

============================================================
FACULTY MEMBERS
============================================================

Professors
----------
• Dr. L. Raja
• Dr. K. Mohaideen Abdul Kadhar
• Dr. S. Sheeba Rani Gnanamalar

Associate Professors
--------------------
• Dr. M. Mohammed Mustafa
• Dr. G. Shobana
• Dr. A. Sivaramakrishnan
• Dr. M. P. Geetha

Assistant Professors
--------------------
• Dr. M. Thenmozhi
• Dr. M. Nivaashini
• Dr. P. Dinesh Kumar
• Dr. T. Kanimozhi
• Dr. L. R. Sujithra
• Dr. C. Rajeshkumar
• Ms. P. Chitra
• Ms. S. Gowri
• Ms. E. Anitha
• Ms. S. Rajalakshmi
• Ms. K. Parvathy
• Ms. M. Sowmiya
• Ms. S. Sowmiya
• Mr. S. Sridharan
• Ms. A. Soundarya
• Ms. V. Sangavi
• Ms. R. Geetha Rajakumari
• Mr. R. Divakar
• Ms. G. Durga Devi
• Ms. N. Pooranam
• Mr. S. Sam Peter
• Ms. K. Parimalam
• Ms. C. Saranya
• Ms. D. Hema Malini
• Ms. P. Anusha Devi

Professors of Practice
----------------------
• Ms. S. V. Uma
• Mr. Alaksandar Jesus Gene

============================================================
STUDENT ACHIEVEMENTS
============================================================

• VOID.V1 Hackathon 2025
  - Sakthivel M (III AI&DS)
  - 4th Place

• Rolls Royce R2 Data Labs Responsible Hackathon
  - Jyothikamalesh S (CSBS)
  - Naveen V
  - Sudarssan N (IV AI&DS)
  - Winner

• Harvard Project for International Relations
  - Sudarssan N (IV AI&DS)
  - Top 200 Participants

• Plastic Free AI Hackathon
  - Sanjai L
  - Naveen Kumar S
  - Gokul C (III AI&DS)
  - Abinaya S (III CSE)
  - Top 15 Finalist

• TANCAM'S TNWISE
  - Sruthi Kumari Jaiswal
  - 4th Place

• Codethon
  - Jayanarayan Menon
  - Jayanth E
  - Kungumapriyaa M
  - Pramod K (II AI&DS)
  - Winners

• Adobe Student Ambassadors
  - Kanika K (II AI&DS)
  - Top 80 in India

• SMARTX Hackathon 2025
  - Shruti Kumari Jaiswal
  - Shiv Kumar Gupta
  - Sumitha R (III AI&DS)
  - 2nd Place

============================================================
EVENTS & ACTIVITIES
============================================================

2025
• OBE Awareness and Attainment Process
• Next Gen C++ Innovation through STL, Concurrency & Beyond
• Node.js & GraphQL
• Training on ROS – Beginner and Intermediate Course

2024
• Conclave 2024
• AI for Future Workforce
• Exploring the Future of Machine Learning and Data Structure
• Cloud Computing Mastery
• Data Science in Action
• Evolution of Gen AI on Cloud Platform
• Future Engineering Demystified
• Drafting a Research Article
• Mastering Data Science Basics
• Beyond Intelligence, Shaping the Future
• Transforming Tomorrow: The Age of AI and Robotics
• Data Science Boot Camp
• Mastering the Data Universe
• Data Expedition

============================================================
RESEARCH
============================================================

The institution encourages faculty members to obtain funding from:

• DST
• AICTE
• TNSCCT
• MHRD
• CSIR
• DRDO
• ISTE
• Industry Partners

Research Support:
• AU Approved Research Supervisors
• Research Facilities
• Publications
• Patents
• Research Grants & Seed Funds
• Consultancy Projects

============================================================
INDUSTRY COLLABORATION
============================================================

• MoUs
• Industry Visits
• Internships
• CoE Activities
• Projects

============================================================
AI&DS OFFICE CONTACT
============================================================

Dr. M. Mohammed Mustafa
Associate Professor & HoD, AI&DS
Phone: +91 4259 200452
Email: hodaids@sece.ac.in

Ms. P. Brindha
Department Office Secretary
Phone: +91 4259 200454
Email: aids_support@sece.ac.in

============================================================
COLLEGE CONTACT
============================================================

Phone: +91 4259 200300
Location: Coimbatore
Email: sece@sece.ac.in

Website: Sri Eshwar College of Engineering
""").strip()

with open(file_path,"w",encoding="utf-8") as f:
  f.write(content)

print(f"Creation successfull")

# %%
# !pip uninstall -y transformers sentence-transformers --q
# !pip install transformers==4.45.2 --q
# !pip install sentence-transformers==3.1.1 --q
print("Installation complete!")

# %%
import os
from llama_index.llms.groq import Groq
from llama_index.core import SimpleDirectoryReader, VectorStoreIndex
from llama_index.embeddings.huggingface import HuggingFaceEmbedding


os.environ["GROQ_API_KEY"]=""

llm=Groq(model="llama-3.1-8b-instant")

embed_model=HuggingFaceEmbedding(model_name="sentence-transformers/all-MiniLM-L6-v2")

file_path="data/sece_dept.txt"

documents=SimpleDirectoryReader(input_files=[file_path]).load_data()

index=VectorStoreIndex.from_documents(documents,embed_model=embed_model)

query_engine=index.as_query_engine(llm=llm)

response= query_engine.query("Give the name of the HOD and his qualifications")
print(response)

# %%
from textwrap import dedent
file_path="data/resume.txt"

content=dedent("""
SIVA BARATH S
 Phone: +91 9025438424 |  Email: sivabarath.s2024aids@sece.ac.in |  | LinkedIn | GitHub
Sri Eshwar College of Engineering
NVKS Sr Sec School
NVKS Hr Sec SchoolB.TECH(AI&DS)
SSLC
HSCCGPA : 8.31 (up to 3 sem)rd
89.1%
89.2%2024-2028 EDUCATION
2023-20242021-2022
PROJECTS
Chronic Disease Progression Tracker
Built an ML-based web application to predict disease severity (Stage I–IV), 12-month progression risk, and
complications for multiple chronic diseases using Random Forest and Gradient Boosting (85–92% accuracy)
with cross-validation.
Developed an interactive dashboard with risk visualization and timeline forecasts, along with features like AI
chatbot, OCR-based prescription scanning, and patient history storage with a scalable backend.
TECH STACK: Python, Flask, MongoDB, HTML, CSS, JavaScript, Chart.js, Pandas, NumPy, OCR
Smart Waste Management & Route Optimization System
Developed a full-stack waste management system with a user app for real-time garbage reporting and monitoring.
Implemented route optimization using OSMnx, NetworkX, Dijkstra, and K-Means for efficient multi-truck collection.
Built an interactive dashboard to visualize houses, optimized routes, and live truck movement.
Developed an ML model for waste classification, an IoT-based smart bin using IR sensors for fill-level detection,
and a separate hardware system for automatic waste segregation using material detection and controlled disposal
mechanism.
TECH STACK: Python, Flask, Leaflet.js, OSMnx, NetworkX, K-Means, Machine Learning, JavaScript, HTML,
CSS, IoT (ESP32, Sensors)
CERTIFICATIONS
Programming in Java - NPTEL
Mastering Data Structures & Algorithms using C and C++
Python Mastery with Generative AI: Coding to AI Integration
Certification in C  | IIT Bombay
Certification in C++ | IIT Bombay
Electronics Foundations: Semiconductor Devices2025
2025
2025
2025
2025
2024
Secured 3 place in Freshathon (ClassLevel) - SECERDACHIEVEMENTS
2025
2025
2026Certified by NPTEL in Programming in Java with 98% score, ranked in Top 1%
PROFILE
Leetcode: 160+ problems solved | GlobalRank:419,065 | Contest Rating : 1500+ | link
SkillRack: 1000+ problems solved | 12 Certificates Recieved | 290+ Bronze | Rank: 21096 | link
SKILLS
Programming - C | C++ | Python| Java
Web Technologies - HTML | CSS | JavaScript | React.js | Node.js
Core Concepts - DSA | OOPS | DBMS
Tools - VSCode | Canva | Excel | PowerPoint | Jupyter Notebook | GitHub | Git
DataBases - MongoDB | MySQL Workbench Self Intro
Finalist – India Innovates Hackathon 2026 (Top 68 out of 1050+ teams;
Ranked 10th in Urban Solutions domain)
""").strip()

with open(file_path,"w",encoding="utf-8") as f:
  f.write(content)

print(f"Creation successfull")

# %%
import os
from llama_index.llms.groq import Groq
from llama_index.core import SimpleDirectoryReader, VectorStoreIndex
from llama_index.embeddings.huggingface import HuggingFaceEmbedding


os.environ["GROQ_API_KEY"]=""

llm=Groq(model="llama-3.1-8b-instant")

embed_model=HuggingFaceEmbedding(model_name="sentence-transformers/all-MiniLM-L6-v2")

documents = SimpleDirectoryReader(
    input_dir="data"
).load_data()

index=VectorStoreIndex.from_documents(documents,embed_model=embed_model)

query_engine = index.as_query_engine(
    llm=llm,
    similarity_top_k=15
)

response = query_engine.query("""
Using all available documents:

1. Who is the HOD of the AI&DS department?
2. Give the HOD's designation.
3. Summarize Siva Barath's resume in 5 bullet points.
""")

print(response)

# %%
from sentence_transformers import SentenceTransformer
model=SentenceTransformer('all-MiniLM-L6-v2')
print("Model loaded successfully")

# %%
sentence="ETL is used to clean and transform data"
embedding=model.encode(sentence)

print(f"Input sentence: '{sentence}'")
print()
print(f"Embedding type: '{type(embedding)}'")
print(f"Embedding shape: '{embedding.shape}'")
print(f"First 10 numbers: '{embedding[:10].round(4)}'")
print(f"Min value: {embedding.min():.4f}")
print(f"Max value: {embedding.max():.4f}")

# %%
sentences=[
    "CSK has 5 trophies",
    "CSK is the best IPL team ever",
    "My name is Siva Barath",
]

embedding=model.encode(sentences)

print(f"Number of sentences: {len(sentences)}")
print(f"Shape of embeddings array: {embedding.shape}")
print()

# %%
import numpy as np
def cosine_similarity(vec_a,vec_b):
  dot_product=np.dot(vec_a,vec_b)

  norm_a=np.linalg.norm(vec_a)
  norm_b=np.linalg.norm(vec_b)

  return dot_product/(norm_a*norm_b)

sim_01=cosine_similarity(embedding[0],embedding[1])
sim_02=cosine_similarity(embedding[0],embedding[2])
sim_03=cosine_similarity(embedding[1],embedding[2])

print(f"Similarity (0 vs 1):{sim_01:.4f} ")
print(f"Similarity (0 vs 2):{sim_02:.4f} ")
print(f"Similarity (1 vs 2):{sim_03:.4f} ")

# %%
# !pip install langchain langchain-community langchain-groq faiss-cpu sentence-transformers PyPDF2 pypdf --q

# %%
# !pip install fpdf --q

# %%
from fpdf import FPDF
import os

pdf=FPDF()
pdf.add_page()
pdf.set_font("Arial",size=12)

os.makedirs("sample_data",exist_ok=True)

content=[
    """

SRI ESHWAR COLLEGE OF ENGINEERING (SECE)
DEPARTMENT OF ARTIFICIAL INTELLIGENCE & DATA SCIENCE (AI&DS)

============================================================
OVERVIEW
============================================================

Highest Salary Package: 44 LPA
Recruiters: 120+
Publications: 30+
Patents: 10+

------------------------------------------------------------
PROGRAMME SCOPE
------------------------------------------------------------

The biggest technological advancement of this century is enabling machines to think and act like humans through Artificial Intelligence powered by Data. AI-driven solutions are becoming dominant in every aspect of human life. Examples include Autonomous Vehicles, Virtual Assistants (Alexa, Siri), Domestic Assistant Robots, and many emerging intelligent systems.

AI & Data Science is one of the most promising fields for students interested in data, analytics, and intelligent systems.

------------------------------------------------------------
LEARNING SCOPE
------------------------------------------------------------

Students will be able to:

• Design, develop, and apply AI & DS solutions for real-world business problems.
• Develop analytical and critical thinking skills.
• Gain expertise in:
  - Deep Learning
  - Computer Vision
  - Data Science
  - Predictive Analytics
  - AR/VR
  - Natural Language Processing
  - Robotics
  - Software Technologies
  - Object-Oriented Programming
  - Database Management Systems

------------------------------------------------------------
CAREER PROGRESSION
------------------------------------------------------------

Career opportunities include:

• Data Scientist
• Data Analyst
• Machine Learning Architect
• Software Developer

Industries:
• Healthcare
• Travel & Transportation
• FMCG
• Technology & Analytics

============================================================
VISION
============================================================

To build a conducive academic and research environment in Artificial Intelligence and Data Science for enabling global education, research, and entrepreneurship.

============================================================
MISSION
============================================================

1. Update and enrich curriculum by integrating global trends and technological advancements.
2. Promote research through state-of-the-art infrastructure and emerging technologies.
3. Empower faculty through continuous upskilling, international collaborations, and research engagement.
4. Encourage industry-aligned learning, innovation, and entrepreneurship for solving societal challenges.

============================================================
PROGRAMME DETAILS
============================================================

• Programme Educational Objectives (PEOs)
• Programme Outcomes (POs)
• Programme Specific Outcomes (PSOs)
• Curriculum & Syllabus
• Programme Assessment Committee
• Board of Studies

============================================================
CORPORATE ADVISORY BOARD
============================================================

1. Mr. Subrahmanian Kumaraswamy
   Data Architect, NTT Data

2. Mr. Bagavath P
   Technical Lead, BNY Mellon Technology

3. Mr. A. Ravi Kasthuri
   CTO, Presentation.AI

4. Mr. Karthick Shanmugasundaram
   Senior Software Developer, GUSTO, USA

5. Ms. Aishwarya Sterling James
   Senior Executive, Mad Street Den (Vue.ai)

============================================================
ENHANCED LEARNING
============================================================

LABORATORIES
------------
• Programming Languages Laboratory
• Full Stack Development Laboratory
• Artificial Intelligence Laboratory
• Data Science Laboratory
• Data Visualization & Exploration Laboratory
• Machine Learning Laboratory
• Computer Vision Laboratory
• Natural Language Programming Laboratory

CENTRES OF EXCELLENCE (CoE)
---------------------------
• CoE in Data Science
• CoE in AI and Robotics

VALUE ADDED COURSES
-------------------
• Mastering OpenCV
• Application Development using KNIME
• Mastering TensorFlow and Keras
• Apache Spark and Databricks
• Application Development using Golang
• Prompt Engineering

INNOVATIVE TEACHING METHODS
---------------------------
• Experiential Learning through Python Frameworks
• Team Assisted Individualization using Google Colab
• Dashboard Creation using Visualization Tools
• Carnegie Learning for Case-Based Analysis
• Personalized Learning using Squirrel AI

============================================================
HEAD OF THE DEPARTMENT
============================================================

Dr. G. Sathish Kumar
Associate Professor & HOD

============================================================
FACULTY MEMBERS
============================================================

Professors
----------
• Dr. L. Raja
• Dr. K. Mohaideen Abdul Kadhar
• Dr. S. Sheeba Rani Gnanamalar

Associate Professors
--------------------
• Dr. M. Mohammed Mustafa
• Dr. G. Shobana
• Dr. A. Sivaramakrishnan
• Dr. M. P. Geetha

Assistant Professors
--------------------
• Dr. M. Thenmozhi
• Dr. M. Nivaashini
• Dr. P. Dinesh Kumar
• Dr. T. Kanimozhi
• Dr. L. R. Sujithra
• Dr. C. Rajeshkumar
• Ms. P. Chitra
• Ms. S. Gowri
• Ms. E. Anitha
• Ms. S. Rajalakshmi
• Ms. K. Parvathy
• Ms. M. Sowmiya
• Ms. S. Sowmiya
• Mr. S. Sridharan
• Ms. A. Soundarya
• Ms. V. Sangavi
• Ms. R. Geetha Rajakumari
• Mr. R. Divakar
• Ms. G. Durga Devi
• Ms. N. Pooranam
• Mr. S. Sam Peter
• Ms. K. Parimalam
• Ms. C. Saranya
• Ms. D. Hema Malini
• Ms. P. Anusha Devi

Professors of Practice
----------------------
• Ms. S. V. Uma
• Mr. Alaksandar Jesus Gene

============================================================
STUDENT ACHIEVEMENTS
============================================================

• VOID.V1 Hackathon 2025
  - Sakthivel M (III AI&DS)
  - 4th Place

• Rolls Royce R2 Data Labs Responsible Hackathon
  - Jyothikamalesh S (CSBS)
  - Naveen V
  - Sudarssan N (IV AI&DS)
  - Winner

• Harvard Project for International Relations
  - Sudarssan N (IV AI&DS)
  - Top 200 Participants

• Plastic Free AI Hackathon
  - Sanjai L
  - Naveen Kumar S
  - Gokul C (III AI&DS)
  - Abinaya S (III CSE)
  - Top 15 Finalist

• TANCAM'S TNWISE
  - Sruthi Kumari Jaiswal
  - 4th Place

• Codethon
  - Jayanarayan Menon
  - Jayanth E
  - Kungumapriyaa M
  - Pramod K (II AI&DS)
  - Winners

• Adobe Student Ambassadors
  - Kanika K (II AI&DS)
  - Top 80 in India

• SMARTX Hackathon 2025
  - Shruti Kumari Jaiswal
  - Shiv Kumar Gupta
  - Sumitha R (III AI&DS)
  - 2nd Place

============================================================
EVENTS & ACTIVITIES
============================================================

2025
• OBE Awareness and Attainment Process
• Next Gen C++ Innovation through STL, Concurrency & Beyond
• Node.js & GraphQL
• Training on ROS – Beginner and Intermediate Course

2024
• Conclave 2024
• AI for Future Workforce
• Exploring the Future of Machine Learning and Data Structure
• Cloud Computing Mastery
• Data Science in Action
• Evolution of Gen AI on Cloud Platform
• Future Engineering Demystified
• Drafting a Research Article
• Mastering Data Science Basics
• Beyond Intelligence, Shaping the Future
• Transforming Tomorrow: The Age of AI and Robotics
• Data Science Boot Camp
• Mastering the Data Universe
• Data Expedition

============================================================
RESEARCH
============================================================

The institution encourages faculty members to obtain funding from:

• DST
• AICTE
• TNSCCT
• MHRD
• CSIR
• DRDO
• ISTE
• Industry Partners

Research Support:
• AU Approved Research Supervisors
• Research Facilities
• Publications
• Patents
• Research Grants & Seed Funds
• Consultancy Projects

============================================================
INDUSTRY COLLABORATION
============================================================

• MoUs
• Industry Visits
• Internships
• CoE Activities
• Projects

============================================================
AI&DS OFFICE CONTACT
============================================================

Dr. M. Mohammed Mustafa
Associate Professor & HoD, AI&DS
Phone: +91 4259 200452
Email: hodaids@sece.ac.in

Ms. P. Brindha
Department Office Secretary
Phone: +91 4259 200454
Email: aids_support@sece.ac.in

============================================================
COLLEGE CONTACT
============================================================

Phone: +91 4259 200300
Location: Coimbatore
Email: sece@sece.ac.in

Website: Sri Eshwar College of Engineering

    """
]

content[0] = content[0].replace("•", "-")
content[0] = content[0].replace("–", "-")
content[0] = content[0].replace("’", "'")
content[0] = content[0].replace("“", '"')
content[0] = content[0].replace("”", '"')

for line in content:
  pdf.multi_cell(0,10,line)

pdf_file="sample_data/dept.pdf"
pdf.output(pdf_file)
print(f"PDF saved as {pdf_file}")

# %%
import os
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import CharacterTextSplitter
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_groq import ChatGroq

os.environ["GROQ_API_KEY"] = ""

loader = PyPDFLoader("sample_data/dept.pdf")
pages = loader.load()
splitter = CharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=50
)

documents = splitter.split_documents(pages)
embedding = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

db = FAISS.from_documents(
    documents,
    embedding
)

llm = ChatGroq(
    model="llama-3.1-8b-instant",
    temperature=0
)
prompt = PromptTemplate.from_template("""
Use the following context to answer the question.
If the answer is not present in the context, say:
"I could not find that information in the document."

Context:
{context}

Question:
{question}

Answer:
""")

parser = StrOutputParser()

def ask_pdf(query: str):
    docs = db.similarity_search(query, k=5)

    context = "\n\n".join(
        [doc.page_content for doc in docs]
    )

    chain = prompt | llm | parser

    return chain.invoke({
        "context": context,
        "question": query
    })

while True:
    query = input("\nAsk a question (or type 'exit'): ")

    if query.lower() == "exit":
        print("Goodbye!")
        break

    answer = ask_pdf(query)

    print("\nAnswer:\n")
    print(answer)

# %%
# !pip install gradio

# %%
import gradio as gr

def calculate(a, b, op):
    if op == "+":
        return a + b
    elif op == "-":
        return a - b
    elif op == "*":
        return a * b
    elif op == "/":
        return a / b if b != 0 else "Cannot divide by zero"

gr.Interface(
    fn=calculate,
    inputs=[
        gr.Number(),
        gr.Number(),
        gr.Radio(["+", "-", "*", "/"])
    ],
    outputs="text"
).launch()
